# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiiyer/ERA1/blob/main/Session-5/S5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
from torchsummary import summary
from model import Net
from utils import train, test

# CUDA?
cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)

# Train data transformations
train_transforms = transforms.Compose([
    transforms.RandomApply([transforms.CenterCrop(22), ], p=0.1),
    transforms.Resize((28, 28)),
    transforms.RandomRotation((-15., 15.), fill=0),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
])

# Test data transformations
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.4081,))
])

train_data = datasets.MNIST('../data', train=True, download=True, transform=train_transforms)
test_data = datasets.MNIST('../data', train=False, download=True, transform=train_transforms)

batch_size = 512

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 2, 'pin_memory': True}

test_loader = torch.utils.data.DataLoader(test_data, **kwargs)
train_loader = torch.utils.data.DataLoader(train_data, **kwargs)

batch_data, batch_label = next(iter(train_loader)) 

fig = plt.figure()

for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.tight_layout()
    plt.imshow(batch_data[i].squeeze(0), cmap='gray')
    plt.title(batch_label[i].item())
    plt.xticks([])
    plt.yticks([])

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = Net().to(device)
summary(model, input_size=(1, 28, 28))

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1, verbose=True)
criterion = torch.nn.CrossEntropyLoss()
num_epochs = 20

train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

for epoch in range(1, num_epochs + 1):
    print(f'Epoch {epoch}')
    train_loss, train_accuracy = train(model, device, train_loader, optimizer, criterion)
    test_loss, test_accuracy = test(model, device, test_loader, criterion)
    scheduler.step()

    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

fig, axs = plt.subplots(2, 2, figsize=(15, 10))
axs[0, 0].plot(train_losses)
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_accuracies)
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_accuracies)
axs[1, 1].set_title("Test Accuracy")

plt.show()
# Out:
# CUDA Available? True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             320
#             Conv2d-2           [-1, 64, 24, 24]          18,496
#             Conv2d-3          [-1, 128, 10, 10]          73,856
#             Conv2d-4            [-1, 256, 8, 8]         295,168
#             Linear-5                   [-1, 50]         204,850
#             Linear-6                   [-1, 10]             510
# ================================================================
# Total params: 593,200
# Trainable params: 593,200
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.67
# Params size (MB): 2.26
# Estimated Total Size (MB): 2.94
# ----------------------------------------------------------------
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Train: Loss=0.3270 Batch_id=117 Accuracy=52.38: 100%|██████████| 118/118 [00:27<00:00,  4.25it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: Loss=0.2040 Batch_id=117 Accuracy=93.38: 100%|██████████| 118/118 [00:22<00:00,  5.34it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: Loss=0.1259 Batch_id=117 Accuracy=95.92: 100%|██████████| 118/118 [00:22<00:00,  5.27it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: Loss=0.0862 Batch_id=117 Accuracy=96.91: 100%|██████████| 118/118 [00:22<00:00,  5.25it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: Loss=0.0599 Batch_id=117 Accuracy=97.44: 100%|██████████| 118/118 [00:24<00:00,  4.87it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: Loss=0.1095 Batch_id=117 Accuracy=97.72: 100%|██████████| 118/118 [00:22<00:00,  5.33it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: Loss=0.0780 Batch_id=117 Accuracy=97.96: 100%|██████████| 118/118 [00:22<00:00,  5.30it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: Loss=0.0359 Batch_id=117 Accuracy=98.24: 100%|██████████| 118/118 [00:21<00:00,  5.37it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 9
# Train: Loss=0.0269 Batch_id=117 Accuracy=98.31: 100%|██████████| 118/118 [00:22<00:00,  5.34it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 10
# Train: Loss=0.0120 Batch_id=117 Accuracy=98.45: 100%|██████████| 118/118 [00:22<00:00,  5.32it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 11
# Train: Loss=0.1035 Batch_id=117 Accuracy=98.51: 100%|██████████| 118/118 [00:22<00:00,  5.32it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 12
# Train: Loss=0.0138 Batch_id=117 Accuracy=98.62: 100%|██████████| 118/118 [00:23<00:00,  5.08it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 13
# Train: Loss=0.0471 Batch_id=117 Accuracy=98.72: 100%|██████████| 118/118 [00:22<00:00,  5.35it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 14
# Train: Loss=0.1123 Batch_id=117 Accuracy=98.71: 100%|██████████| 118/118 [00:21<00:00,  5.40it/s]
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 15
# Train: Loss=0.0132 Batch_id=117 Accuracy=98.82: 100%|██████████| 118/118 [00:22<00:00,  5.34it/s]
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 16
# Train: Loss=0.0208 Batch_id=117 Accuracy=99.08: 100%|██████████| 118/118 [00:22<00:00,  5.31it/s]
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 17
# Train: Loss=0.0728 Batch_id=117 Accuracy=99.14: 100%|██████████| 118/118 [00:22<00:00,  5.34it/s]
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 18
# Train: Loss=0.0466 Batch_id=117 Accuracy=99.10: 100%|██████████| 118/118 [00:22<00:00,  5.31it/s]
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 19
# Train: Loss=0.0525 Batch_id=117 Accuracy=99.19: 100%|██████████| 118/118 [00:22<00:00,  5.32it/s]
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 20
# Train: Loss=0.0551 Batch_id=117 Accuracy=99.14: 100%|██████████| 118/118 [00:23<00:00,  5.12it/s]
# Adjusting learning rate of group 0 to 1.0000e-03.
